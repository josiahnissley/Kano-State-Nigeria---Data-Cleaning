# %% [markdown]
# <a href="https://colab.research.google.com/github/josiahnissley/Kano-State-Nigeria---Data-Cleaning/blob/main/Data_Cleaning_30_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %%
def wrangler(path) -> pd.DataFrame:

  df = pd.read_csv(path, skiprows=20) # Read csv file

  df['date'] = df.apply(lambda x: f"{int(x['YEAR'])}-{int(x['DOY'])}", axis=1) # Date feature engineering
  df['date'] = pd.to_datetime(df['date'], format='%Y-%j') # Date feature engineering
  df.index = df['date'] # Date as index
  df.drop(['date', 'YEAR', 'DOY'], axis=1, inplace=True) # Drop irrelevant columns

  # checks if there are missing values or duplicates
  for col in df.columns:
    if df[col].isna().any():
      print(f'{col} has {df[col].isna().sum()} missing values, please check to decide imputation or drop')
    elif df.duplicated().any():
      print(f'{col} has {df.duplicated().sum()} duplicate values, please check to decide if drop is necessary')
    else:
      continue
  df.rename(columns={'PRECTOTCORR': 'PRECIPITATION'}, inplace=True) # Rename column
  print(df.shape)



  return df

# %% [markdown]
# ## 30. Takai, South Kano

# %%
Takai = 'https://raw.githubusercontent.com/OmdenaAI/KanoNigeriaChapter_SmartFarming/refs/heads/main/Weather_data_36_local_government_area/Southern%20Kano%20State/30.%20Takai%2C%20S%20Kano.csv'
Takai_df = wrangler(Takai)
# Out:
# (4018, 12)

# %%
Takai_df.head(10)
# Out:
#              T2M  T2M_MAX  T2M_MIN  RH2M  PRECIPITATION  WS2M  WS2M_MAX  \
# date
# 2014-01-01 20.95    32.19    11.52 17.47           0.00  1.24      2.27
# 2014-01-02 20.84    31.07    12.26 15.76           0.00  1.44      2.56
# 2014-01-03 21.42    31.05    13.84 16.40           0.00  1.80      3.43
# 2014-01-04 20.97    31.14    12.89 19.33           0.00  1.75      3.49
# 2014-01-05 20.89    30.88    12.65 21.42           0.00  1.74      2.94
# 2014-01-06 20.33    29.84    12.96 23.70           0.00  1.73      3.14
# 2014-01-07 20.76    30.89    12.62 22.81           0.00  1.76      3.41
# 2014-01-08 21.07    31.25    12.51 23.19           0.00  1.84      3.53
# 2014-01-09 20.87    31.04    12.19 20.76           0.00  1.80      3.39
# 2014-01-10 20.82    30.37    13.12 22.01           0.00  2.04      3.25
#
#             WS2M_MIN  WD2M  GWETTOP  GWETROOT  GWETPROF
# date
# 2014-01-01      0.67 26.40     0.17      0.26      0.26
# ...

# %%
Takai_df.describe()
# Out:
#            T2M  T2M_MAX  T2M_MIN     RH2M  PRECIPITATION     WS2M  WS2M_MAX  \
# count 4,018.00 4,018.00 4,018.00 4,018.00       4,018.00 4,018.00  4,018.00
# mean     26.61    34.57    20.00    45.53           2.37     1.30      2.27
# std       3.97     4.07     4.65    23.50          12.51     0.49      0.85
# min      14.64    21.23     5.36     5.31           0.00     0.32      0.48
# 25%      24.29    31.40    16.40    23.99           0.00     0.91      1.58
# 50%      26.53    34.50    21.45    44.61           0.00     1.28      2.26
# 75%      29.56    37.67    23.29    65.99           0.85     1.65      2.88
# max      35.85    44.20    29.45    94.95         390.00     3.15      5.82
#
#        WS2M_MIN     WD2M  GWETTOP  GWETROOT  GWETPROF
# count  4,018.00 4,018.00 4,018.00  4,018.00  4,018.00
# mean       0.59   133.97     0.31      0.34      0.35
# std        0.32    89.93     0.19      0.14      0.14
# min        0.01     0.20     0.07      0.23      0.23
# ...

# %%
# Cleaned file ready for EDA
Takai_df.to_csv('Takai_df_Cleaned.csv', index='date')

# %% [markdown]
# ## 31. Albasu, South Kano

# %%
Albasu = 'https://raw.githubusercontent.com/OmdenaAI/KanoNigeriaChapter_SmartFarming/refs/heads/main/Weather_data_36_local_government_area/Southern%20Kano%20State/31.%20Albasu%2C%20S%20Kano.csv'
Albasu_df = wrangler(Albasu)
# Out:
# (4018, 12)

# %%
Albasu_df.head(10)
# Out:
#              T2M  T2M_MAX  T2M_MIN  RH2M  PRECIPITATION  WS2M  WS2M_MAX  \
# date
# 2014-01-01 20.95    32.19    11.52 17.47           0.00  1.24      2.27
# 2014-01-02 20.84    31.07    12.26 15.76           0.00  1.44      2.56
# 2014-01-03 21.42    31.05    13.84 16.40           0.00  1.80      3.43
# 2014-01-04 20.97    31.14    12.89 19.33           0.00  1.75      3.49
# 2014-01-05 20.89    30.88    12.65 21.42           0.00  1.74      2.94
# 2014-01-06 20.33    29.84    12.96 23.70           0.00  1.73      3.14
# 2014-01-07 20.76    30.89    12.62 22.81           0.00  1.76      3.41
# 2014-01-08 21.07    31.25    12.51 23.19           0.00  1.84      3.53
# 2014-01-09 20.87    31.04    12.19 20.76           0.00  1.80      3.39
# 2014-01-10 20.82    30.37    13.12 22.01           0.00  2.04      3.25
#
#             WS2M_MIN  WD2M  GWETTOP  GWETROOT  GWETPROF
# date
# 2014-01-01      0.67 26.40     0.17      0.26      0.26
# ...

# %%
Albasu_df.describe()
# Out:
#            T2M  T2M_MAX  T2M_MIN     RH2M  PRECIPITATION     WS2M  WS2M_MAX  \
# count 4,018.00 4,018.00 4,018.00 4,018.00       4,018.00 4,018.00  4,018.00
# mean     26.61    34.57    20.00    45.53           2.37     1.30      2.27
# std       3.97     4.07     4.65    23.50          12.51     0.49      0.85
# min      14.64    21.23     5.36     5.31           0.00     0.32      0.48
# 25%      24.29    31.40    16.40    23.99           0.00     0.91      1.58
# 50%      26.53    34.50    21.45    44.61           0.00     1.28      2.26
# 75%      29.56    37.67    23.29    65.99           0.85     1.65      2.88
# max      35.85    44.20    29.45    94.95         390.00     3.15      5.82
#
#        WS2M_MIN     WD2M  GWETTOP  GWETROOT  GWETPROF
# count  4,018.00 4,018.00 4,018.00  4,018.00  4,018.00
# mean       0.59   133.97     0.31      0.34      0.35
# std        0.32    89.93     0.19      0.14      0.14
# min        0.01     0.20     0.07      0.23      0.23
# ...

# %%
# Cleaned file ready for EDA
Albasu_df.to_csv('Albasu_df_Cleaned.csv', index='date')

# %% [markdown]
# ## 32. Gaya, South Kano

# %%
Gaya = 'https://raw.githubusercontent.com/OmdenaAI/KanoNigeriaChapter_SmartFarming/refs/heads/main/Weather_data_36_local_government_area/Southern%20Kano%20State/32.%20Gaya%2C%20S%20Kano.csv'
Gaya_df = wrangler(Gaya)
# Out:
# (4018, 12)

# %%
Gaya_df.head(10)
# Out:
#              T2M  T2M_MAX  T2M_MIN  RH2M  PRECIPITATION  WS2M  WS2M_MAX  \
# date
# 2014-01-01 19.92    31.58    10.23 18.48           0.00  0.90      1.70
# 2014-01-02 20.21    29.80    12.59 15.86           0.00  1.07      1.85
# 2014-01-03 20.56    30.12    12.44 16.93           0.00  1.33      2.46
# 2014-01-04 20.51    30.72    12.47 19.74           0.00  1.34      2.46
# 2014-01-05 20.17    29.41    12.13 22.80           0.00  1.23      2.10
# 2014-01-06 19.96    29.13    13.14 24.67           0.00  1.28      2.22
# 2014-01-07 20.46    30.48    12.45 24.61           0.00  1.27      2.44
# 2014-01-08 20.77    30.83    12.34 24.69           0.00  1.33      2.42
# 2014-01-09 20.48    30.48    12.03 21.93           0.00  1.34      2.26
# 2014-01-10 20.38    29.59    12.96 22.86           0.00  1.54      2.52
#
#             WS2M_MIN  WD2M  GWETTOP  GWETROOT  GWETPROF
# date
# 2014-01-01      0.50 39.40     0.19      0.24      0.26
# ...

# %%
Gaya_df.describe()
# Out:
#            T2M  T2M_MAX  T2M_MIN     RH2M  PRECIPITATION     WS2M  WS2M_MAX  \
# count 4,018.00 4,018.00 4,018.00 4,018.00       4,018.00 4,018.00  4,018.00
# mean     26.43    34.75    19.62    45.38           2.07     0.83      1.44
# std       4.24     4.18     4.92    22.04           8.85     0.43      0.73
# min      13.18    18.83     5.88     6.26           0.00     0.10      0.21
# 25%      23.86    31.78    15.68    25.46           0.00     0.45      0.78
# 50%      26.82    34.77    21.48    44.49           0.00     0.84      1.45
# 75%      29.60    37.97    23.25    64.02           0.79     1.14      2.00
# max      35.18    44.18    29.01    94.77         181.37     2.33      3.46
#
#        WS2M_MIN     WD2M  GWETTOP  GWETROOT  GWETPROF
# count  4,018.00 4,018.00 4,018.00  4,018.00  4,018.00
# mean       0.38   135.51     0.31      0.31      0.34
# std        0.25    93.80     0.16      0.12      0.13
# min        0.00     0.10     0.11      0.20      0.21
# ...

# %%
# Cleaned file ready for EDA
Gaya_df.to_csv('Gaya_df_Cleaned.csv', index='date')

# %% [markdown]
# ## 33. Ajingi, South Kano

# %%
Ajingi = 'https://raw.githubusercontent.com/OmdenaAI/KanoNigeriaChapter_SmartFarming/refs/heads/main/Weather_data_36_local_government_area/Southern%20Kano%20State/33.%20Ajingi%2C%20S%20Kano.csv'
Ajingi_df = wrangler(Ajingi)
# Out:
# (4018, 12)

# %%
Ajingi_df.head(10)
# Out:
#              T2M  T2M_MAX  T2M_MIN  RH2M  PRECIPITATION  WS2M  WS2M_MAX  \
# date
# 2014-01-01 19.92    31.58    10.23 18.48           0.00  0.90      1.70
# 2014-01-02 20.21    29.80    12.59 15.86           0.00  1.07      1.85
# 2014-01-03 20.56    30.12    12.44 16.93           0.00  1.33      2.46
# 2014-01-04 20.51    30.72    12.47 19.74           0.00  1.34      2.46
# 2014-01-05 20.17    29.41    12.13 22.80           0.00  1.23      2.10
# 2014-01-06 19.96    29.13    13.14 24.67           0.00  1.28      2.22
# 2014-01-07 20.46    30.48    12.45 24.61           0.00  1.27      2.44
# 2014-01-08 20.77    30.83    12.34 24.69           0.00  1.33      2.42
# 2014-01-09 20.48    30.48    12.03 21.93           0.00  1.34      2.26
# 2014-01-10 20.38    29.59    12.96 22.86           0.00  1.54      2.52
#
#             WS2M_MIN  WD2M  GWETTOP  GWETROOT  GWETPROF
# date
# 2014-01-01      0.50 39.40     0.19      0.24      0.26
# ...

# %%
Ajingi_df.describe()
# Out:
#            T2M  T2M_MAX  T2M_MIN     RH2M  PRECIPITATION     WS2M  WS2M_MAX  \
# count 4,018.00 4,018.00 4,018.00 4,018.00       4,018.00 4,018.00  4,018.00
# mean     26.43    34.75    19.62    45.38           2.07     0.83      1.44
# std       4.24     4.18     4.92    22.04           8.85     0.43      0.73
# min      13.18    18.83     5.88     6.26           0.00     0.10      0.21
# 25%      23.86    31.78    15.68    25.46           0.00     0.45      0.78
# 50%      26.82    34.77    21.48    44.49           0.00     0.84      1.45
# 75%      29.60    37.97    23.25    64.02           0.79     1.14      2.00
# max      35.18    44.18    29.01    94.77         181.37     2.33      3.46
#
#        WS2M_MIN     WD2M  GWETTOP  GWETROOT  GWETPROF
# count  4,018.00 4,018.00 4,018.00  4,018.00  4,018.00
# mean       0.38   135.51     0.31      0.31      0.34
# std        0.25    93.80     0.16      0.12      0.13
# min        0.00     0.10     0.11      0.20      0.21
# ...

# %%
# Cleaned file ready for EDA
Ajingi_df.to_csv('Ajingi_df_Cleaned.csv', index='date')

# %% [markdown]
# ## 33. Wudil, South Kano

# %%
Wudil = 'https://raw.githubusercontent.com/OmdenaAI/KanoNigeriaChapter_SmartFarming/refs/heads/main/Weather_data_36_local_government_area/Southern%20Kano%20State/34.%20Wudil%2C%20S%20Kano.csv'
Wudil_df = wrangler(Wudil)
# Out:
# (4018, 12)

# %%
Wudil_df.head(10)
# Out:
#              T2M  T2M_MAX  T2M_MIN  RH2M  PRECIPITATION  WS2M  WS2M_MAX  \
# date
# 2014-01-01 19.92    31.58    10.23 18.48           0.00  0.90      1.70
# 2014-01-02 20.21    29.80    12.59 15.86           0.00  1.07      1.85
# 2014-01-03 20.56    30.12    12.44 16.93           0.00  1.33      2.46
# 2014-01-04 20.51    30.72    12.47 19.74           0.00  1.34      2.46
# 2014-01-05 20.17    29.41    12.13 22.80           0.00  1.23      2.10
# 2014-01-06 19.96    29.13    13.14 24.67           0.00  1.28      2.22
# 2014-01-07 20.46    30.48    12.45 24.61           0.00  1.27      2.44
# 2014-01-08 20.77    30.83    12.34 24.69           0.00  1.33      2.42
# 2014-01-09 20.48    30.48    12.03 21.93           0.00  1.34      2.26
# 2014-01-10 20.38    29.59    12.96 22.86           0.00  1.54      2.52
#
#             WS2M_MIN  WD2M  GWETTOP  GWETROOT  GWETPROF
# date
# 2014-01-01      0.50 39.40     0.19      0.24      0.26
# ...

# %%
Wudil_df.describe()
# Out:
#            T2M  T2M_MAX  T2M_MIN     RH2M  PRECIPITATION     WS2M  WS2M_MAX  \
# count 4,018.00 4,018.00 4,018.00 4,018.00       4,018.00 4,018.00  4,018.00
# mean     26.43    34.75    19.62    45.38           2.07     0.83      1.44
# std       4.24     4.18     4.92    22.04           8.85     0.43      0.73
# min      13.18    18.83     5.88     6.26           0.00     0.10      0.21
# 25%      23.86    31.78    15.68    25.46           0.00     0.45      0.78
# 50%      26.82    34.77    21.48    44.49           0.00     0.84      1.45
# 75%      29.60    37.97    23.25    64.02           0.79     1.14      2.00
# max      35.18    44.18    29.01    94.77         181.37     2.33      3.46
#
#        WS2M_MIN     WD2M  GWETTOP  GWETROOT  GWETPROF
# count  4,018.00 4,018.00 4,018.00  4,018.00  4,018.00
# mean       0.38   135.51     0.31      0.31      0.34
# std        0.25    93.80     0.16      0.12      0.13
# min        0.00     0.10     0.11      0.20      0.21
# ...

# %%
# Cleaned file ready for EDA
Wudil_df.to_csv('Wudil_df_Cleaned.csv', index='date')
